# %%
import pandas as pd

# %%
google_document_xlsx = "https://docs.google.com/spreadsheets/d/1VaDe0D14U3fZAWtx0wMXtSUT1_EDL5mUaNuGjxJ6y04/export?format=xlsx"

# %%
# !wget {google_document_xlsx} -O /tmp/prices_scans.xlsx
# Out:
# --2025-04-30 09:29:03--  https://docs.google.com/spreadsheets/d/1VaDe0D14U3fZAWtx0wMXtSUT1_EDL5mUaNuGjxJ6y04/export?format=xlsx
# Resolving docs.google.com (docs.google.com)... 216.58.211.238, 2a00:1450:4026:808::200e
# Connecting to docs.google.com (docs.google.com)|216.58.211.238|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://doc-10-24-sheets.googleusercontent.com/export/54bogvaave6cua4cdnls17ksc4/4uh8rjar5krgsq60sintqid9s8/1746005340000/116312231347809998123/*/1VaDe0D14U3fZAWtx0wMXtSUT1_EDL5mUaNuGjxJ6y04?format=xlsx [following]
# Warning: wildcards not supported in HTTP.
# --2025-04-30 09:29:03--  https://doc-10-24-sheets.googleusercontent.com/export/54bogvaave6cua4cdnls17ksc4/4uh8rjar5krgsq60sintqid9s8/1746005340000/116312231347809998123/*/1VaDe0D14U3fZAWtx0wMXtSUT1_EDL5mUaNuGjxJ6y04?format=xlsx
# Resolving doc-10-24-sheets.googleusercontent.com (doc-10-24-sheets.googleusercontent.com)... 216.58.211.225, 2a00:1450:4026:808::2001
# Connecting to doc-10-24-sheets.googleusercontent.com (doc-10-24-sheets.googleusercontent.com)|216.58.211.225|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘/tmp/prices_scans.xlsx’
#
# /tmp/prices_scans.x     [   <=>              ] 462.21K   891KB/s    in 0.5s
#
# 2025-04-30 09:29:06 (891 KB/s) - ‘/tmp/prices_scans.xlsx’ saved [473308]

# %%
df = pd.read_excel('/tmp/prices_scans.xlsx', header=1)

# %%
df.set_index("Номер картинки",  inplace=True)

# %%
df.head(4)
# Out:
#                 Цена правильная  Цена нейросеть  Ошибка              Строка 1  \
# Номер картинки
# 1                         54.99           54.99     0.0  Вода СВЯТОЙ ИСТОЧНИК
# 2                         59.99           59.99     0.0  Вода Святой источник
# 3                         51.99           51.99     0.0       Вода ШИШКИН ЛЕС
# 4                         24.99           24.99     0.0     Вода КРАСНАЯ ЦЕНА
#
#                    Строка 2                      Строка 3 Строка 4  Строка 5
# Номер картинки
# 1                      1.0л  природная питьевая негаз.ПЭТ      NaN       NaN
# 2                     0,75л          негазированная спорт      NaN       NaN
# 3               питьевая 1л                негазированная      NaN       NaN
# 4                      1,5л                негазированная      NaN       NaN

# %%
DATA_BASE_DIR = "/home/jovyan/names"

# %%
from PIL import Image
img = Image.open(os.path.join(DATA_BASE_DIR, "1.jpg"))
## Загрузка изображения
#img = plt.imread(os.path.join(DATA_BASE_DIR, "1.jpg"))
plt.imshow(img)
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img.shape
# Out:
# (51, 210, 3)
